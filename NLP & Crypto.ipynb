# %%
from time import sleep
from random import randint
import newsapi
import requests
from newspaper import Article
import pprint
import matplotlib.pyplot as plt
import pandas as pd
import re
import nltk
nltk.download('punkt')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package punkt to /Users/prabhatm/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from newspaper import Config
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'
config = Config()
config.browser_user_agent = user_agent
config.request_timeout = 20

# %%
crypto = ['Bitcoin','Ethereum', 'Tether','Binance_coin','XRP',"Cardano","Solana","Polkadot","Dogecoin"]

# %%
#api key
secret = 'b198ef97107247fd87d110e9af018212'
# Define the endpoint
url = 'https://newsapi.org/v2/everything?'
# Specify the query and
# number of returns
parameters = {
    'q': "Bitcoin", # query phrase
    'sortBy':'relevancy',
    "pagesize": 100, # maximum is 100
    "apikey": secret # your own API key
}
# Make the request
response = requests.get(url, params = parameters)
#Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)

bitcoin_sentiments = []
for i in range(100):
    try:
        url = response_json['articles'][i]['url']
        article = Article(url, config=config)
        try:
            article.download()
            article.parse()
        except:
            continue
        article.nlp()
        print("Number" , i + 1)
        text = article.summary
        date = article.publish_date
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        bitcoin_sentiments.append({"text": text, "date": date, "compound": compound, "positive": pos, "negative": neg, "neutral": neu})
    
    except AttributeError:
        pass
# Out:
# {'articles': [{'author': 'Gian M. Volpicelli',
#                'content': 'It was 8:45 in the morning of June 13 when Bill '
#                           'Stewart, the CEO of Maine-based bitcoin mining '
#                           'business Dynamics Mining, received a call from one '
#                           "of his employees. He's like, Every machine inside "
#                           'of … [+3472 chars]',
#                'description': 'Compass Mining grew quickly during crypto’s '
#                               'halcyon days. Now, its customers and their '
#                               'thousands of mining machines are stuck.',
#                'publishedAt': '2022-08-03T11:00:00Z',
#                'source': {'id': 'wired', 'name': 'Wired'},
#                'title': 'The Rise and Fall of a Bitcoin Mining Sensation',
#                'url': 'https://www.wired.com/story/compass-mining-bitcoin-russia/',
# ...

# %%
df_bitcoin = pd.DataFrame.from_dict(bitcoin_sentiments)
df_bitcoin.head()
# Out:
#                                                 text  \
# 0  It was 8:45 in the morning of June 13 when Bil...
# 1  The DOJ has produced more than three terabytes...
# 2  Imagine looking for a single hard drive amidst...
# 3  People in Russia will soon no longer be allowe...
# 4  Elon Musk-owned electric vehicle making compan...
#
#                                date  compound  positive  negative  neutral
# 0         2022-08-03 11:00:00+00:00    0.4019     0.041     0.026    0.933
# 1  2022-08-02 22:02:13.738000+00:00    0.4404     0.046     0.014    0.940
# 2  2022-07-25 18:45:00.709000+00:00   -0.8807     0.044     0.184    0.772
# 3                              None   -0.8814     0.041     0.124    0.835
# 4         2022-07-21 10:35:01+05:30    0.2263     0.053     0.037    0.910

# %%
#api key
secret = 'b198ef97107247fd87d110e9af018212'
# Define the endpoint
url = 'https://newsapi.org/v2/everything?'
# Specify the query and
# number of returns
parameters = {
    'q': "Ethereum", # query phrase
    'sortBy':'relevancy',
    "pagesize": 100, # maximum is 100
    "apikey": secret # your own API key
}
# Make the request
response = requests.get(url, params = parameters)
#Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)

ethereum_sentiments = []
for i in range(100):
    try:
        url = response_json['articles'][i]['url']
        article = Article(url, config=config)
        try:
            article.download()
            article.parse()
        except:
            continue
        article.nlp()
        print("Number" , i + 1)
        text = article.summary
        date = article.publish_date
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        ethereum_sentiments.append({"text": text, "date": date, "compound": compound, "positive": pos, "negative": neg, "neutral": neu})
    
    except AttributeError:
        pass
# Out:
# {'articles': [{'author': 'Kris Holt',
#                'content': 'The non-fungible token\r\n'
#                           ' (NFT) market has fallen off a cliff\r\n'
#                           ", but that's not stopping Instagram from doubling "
#                           'down on digital collectibles. After a test launch '
#                           'in May\r\n'
#                           ', the app is expanding its NF… [+1097 chars]',
#                'description': 'The non-fungible token\r\n'
#                               ' (NFT) market has fallen off a cliff\r\n'
#                               ", but that's not stopping Instagram from "
#                               'doubling down on digital collectibles. After a '
#                               'test launch in May\r\n'
#                               ', the app is expanding its NFT features to more '
#                               'than 100 countries across Africa, Asia-Pa…',
# ...

# %%
df_ethereum = pd.DataFrame.from_dict(ethereum_sentiments)
df_ethereum.head()
# Out:
#                                                 text  date  compound  \
# 0  The non-fungible token (NFT) market has fallen...  None    0.9172
# 1  The Securities and Exchange Commission has cha...  None    0.5106
# 2  Less than two weeks into its soft launch, Game...  None    0.7003
# 3  The Ethereum Merge is significant, and not jus...  None    0.2023
# 4  The Ethereum Merge is significant, and not jus...  None    0.2023
#
#    positive  negative  neutral
# 0     0.128     0.015    0.857
# 1     0.102     0.079    0.819
# 2     0.087     0.057    0.856
# 3     0.053     0.026    0.921
# 4     0.053     0.026    0.921

# %%
#api key
secret = 'b198ef97107247fd87d110e9af018212'
# Define the endpoint
url = 'https://newsapi.org/v2/everything?'
# Specify the query and
# number of returns
parameters = {
    'q': "Tether", # query phrase
    'sortBy':'relevancy',
    "pagesize": 100, # maximum is 100
    "apikey": secret # your own API key
}
# Make the request
response = requests.get(url, params = parameters)
#Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)

tether_sentiments = []
for i in range(100):
    try:
        url = response_json['articles'][i]['url']
        article = Article(url, config=config)
        try:
            article.download()
            article.parse()
        except:
            continue
        article.nlp()
        print("Number" , i + 1)
        text = article.summary
        date = article.publish_date
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        tether_sentiments.append({"text": text, "date": date, "compound": compound, "positive": pos, "negative": neg, "neutral": neu})
    
    except AttributeError:
        pass
# Out:
# {'articles': [{'author': 'Tom Henderson',
#                'content': 'Illustration by Samar Haddad / The Verge\r\n'
#                           '\n'
#                           ' \n'
#                           '\n'
#                           ' You were working. Things were just fine. A '
#                           'landscaper puts a shovel through your buried '
#                           'internet cabling or tree limbs drop and kill a '
#                           'neighborhood’s in… [+10756 chars]',
#                'description': 'Most remote work depends on access to a '
#                               'reliable internet connection. That means '
#                               'finding a way to get back online quickly, '
#                               'either at home or elsewhere. Here’s how you can '
#                               'do it.',
#                'publishedAt': '2022-08-04T12:30:00Z',
#                'source': {'id': 'the-verge', 'name': 'The Verge'},
# ...

# %%
df_tether = pd.DataFrame.from_dict(tether_sentiments)
df_tether.head()
# Out:
#                                                 text  \
# 0  A landscaper puts a shovel through your buried...
# 1  The tether has to withstand enormous forces, a...
# 2  Do you develop on GitHub?\nYou can keep using ...
# 3  July 17 (Reuters) - Consumer-focused digital t...
# 4  Logitech has announced the Aurora collection, ...
#
#                         date  compound  positive  negative  neutral
# 0  2022-08-04 08:30:00-04:00    0.1406     0.055     0.076    0.870
# 1        2022-08-03 00:00:00    0.0000     0.000     0.000    1.000
# 2                       None    0.5255     0.061     0.000    0.939
# 3        2022-07-17 00:00:00    0.9217     0.117     0.000    0.883
# 4        2022-07-26 00:00:00    0.3818     0.066     0.042    0.892

# %%
#api key
secret = 'b198ef97107247fd87d110e9af018212'
# Define the endpoint
url = 'https://newsapi.org/v2/everything?'
# Specify the query and
# number of returns
parameters = {
    'q': "Solana", # query phrase
    'sortBy':'relevancy',
    "pagesize": 100, # maximum is 100
    "apikey": secret # your own API key
}
# Make the request
response = requests.get(url, params = parameters)
#Convert the response to JSON format and pretty print it
response_json = response.json()
pprint.pprint(response_json)

solana_sentiments = []
for i in range(100):
    try:
        url = response_json['articles'][i]['url']
        article = Article(url, config=config)
        try:
            article.download()
            article.parse()
        except:
            continue
        article.nlp()
        print("Number" , i + 1)
        text = article.summary
        date = article.publish_date
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        solana_sentiments.append({"text": text, "date": date, "compound": compound, "positive": pos, "negative": neg, "neutral": neu})
    
    except AttributeError:
        pass
# Out:
# {'articles': [{'author': 'Dan Milmo Technology editor',
#                'content': 'Nearly $6m (£4.9m) has been drained from accounts '
#                           'linked to the Solana crypto network after a hacker '
#                           'targeted 8,000 wallets.\r\n'
#                           'The Solana Foundation, an organisation that '
#                           'supports the blockchain netwo… [+1876 chars]',
#                'description': 'Solana Foundation, supporter of blockchain '
#                               'network, says ‘malicious actor’ has taken '
#                               'fundsNearly $6m (£4.9m) has been drained from '
#                               'accounts linked to the Solana crypto network '
#                               'after a hacker targeted 8,000 wallets.The '
#                               'Solana Foundation, an organisation that s…',
#                'publishedAt': '2022-08-03T18:41:02Z',
# ...

# %%
df_solana = pd.DataFrame.from_dict(solana_sentiments)
df_solana.head()
# Out:
#                                                 text  \
# 0  Photograph: Jakub Porzycki/NurPhoto/REX/Shutte...
# 1  Elsewhere, we highlighted Microsoft’s newly bo...
# 2  The heist comes just days after hackers swiped...
# 3  Do you develop on GitHub?\nYou can keep using ...
# 4  La blockchain Solana est actuellement victime ...
#
#                         date  compound  positive  negative  neutral
# 0        2022-08-03 00:00:00   -0.3612     0.087     0.091    0.822
# 1  2022-08-06 13:00:00+00:00   -0.7311     0.073     0.128    0.800
# 2        2022-08-03 00:00:00   -0.2960     0.057     0.059    0.884
# 3                       None    0.5255     0.061     0.000    0.939
# 4        2022-08-03 00:00:00   -0.3612     0.000     0.030    0.970

# %%
df_bitcoin.describe()
# Out:
#         compound   positive   negative    neutral
# count  97.000000  97.000000  97.000000  97.000000
# mean    0.304621   0.088763   0.047258   0.863907
# std     0.636642   0.056298   0.048867   0.071801
# min    -0.957800   0.000000   0.000000   0.558000
# 25%    -0.296000   0.046000   0.000000   0.827000
# 50%     0.525500   0.077000   0.033000   0.874000
# 75%     0.891000   0.136000   0.066000   0.914000
# max     0.981300   0.217000   0.228000   1.000000

# %%
df_ethereum.describe()
# Out:
#          compound    positive   negative     neutral
# count  100.000000  100.000000  100.00000  100.000000
# mean     0.243307    0.074400    0.04457    0.881030
# std      0.632765    0.052331    0.04628    0.065916
# min     -0.948500    0.000000    0.00000    0.667000
# 25%     -0.230300    0.040750    0.00000    0.840500
# 50%      0.511450    0.068500    0.03300    0.886500
# 75%      0.799725    0.100250    0.06850    0.930000
# max      0.981400    0.239000    0.18900    1.000000

# %%
df_tether.describe()
# Out:
#          compound    positive   negative     neutral
# count  100.000000  100.000000  100.00000  100.000000
# mean     0.260893    0.082810    0.04701    0.850150
# std      0.609927    0.070557    0.04803    0.144333
# min     -0.972300    0.000000    0.00000    0.000000
# 25%     -0.271550    0.024500    0.00000    0.814750
# 50%      0.381800    0.080500    0.03800    0.879000
# 75%      0.830500    0.116250    0.07400    0.916250
# max      0.985800    0.325000    0.19900    1.000000
